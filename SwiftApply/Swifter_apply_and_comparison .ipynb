# %% [markdown]
# ## Swifter – A package which efficiently applies any function to a pandas dataframe or series in the fastest available manner.

# %% [markdown]
# ### Imports and Data

# %%
import pandas as pd
import numpy as np
import swifter

# %%
trips = pd.read_csv('trip.csv')

# %%
print(trips.shape)
trips.head()
# Out:
# (669959, 11)
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4607        70  8/29/2013 14:42        San Jose City Hall
# 2  4130        71  8/29/2013 10:16   Mountain View City Hall
# 3  4251        77  8/29/2013 11:29        San Jose City Hall
# 4  4299        83  8/29/2013 12:02  South Van Ness at Market
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                10  8/29/2013 14:43        San Jose City Hall
# 2                27  8/29/2013 10:17   Mountain View City Hall
# 3                10  8/29/2013 11:30        San Jose City Hall
# 4                66  8/29/2013 12:04            Market at 10th
#
#    end_station_id  bike_id subscription_type zip_code
# 0              66      520        Subscriber    94127
# 1              10      661        Subscriber    95138
# 2              27       48        Subscriber    97214
# 3              10       26        Subscriber    95060
# 4              67      319        Subscriber    94103

# %% [markdown]
# ### Apply any function in the fastest available manner¶

# %%
def bikes_start_end(end_id):
    if end_id > 50:
        return True
    else:
        return False

# %%
# %time trips['bike_station_class'] = trips['end_station_id'].swifter.apply(bikes_start_end)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=669959.0, style=ProgressStyle(descript…
# Wall time: 1.8 s

# %% [markdown]
# #### write code in a vectorized format

# %%
def bikes_start_end_vectorized(end_id):
    return np.where(end_id > 5, True, False)

# %%
# %time trips['bike_station_class_vec'] = trips['end_station_id'].swifter.apply(bikes_start_end_vectorized)
# Out:
# Wall time: 15.6 ms

# %%
trips.head()
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4607        70  8/29/2013 14:42        San Jose City Hall
# 2  4130        71  8/29/2013 10:16   Mountain View City Hall
# 3  4251        77  8/29/2013 11:29        San Jose City Hall
# 4  4299        83  8/29/2013 12:02  South Van Ness at Market
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                10  8/29/2013 14:43        San Jose City Hall
# 2                27  8/29/2013 10:17   Mountain View City Hall
# 3                10  8/29/2013 11:30        San Jose City Hall
# 4                66  8/29/2013 12:04            Market at 10th
#
#    end_station_id  bike_id subscription_type zip_code  bike_station_class  \
# 0              66      520        Subscriber    94127                True
# 1              10      661        Subscriber    95138               False
# 2              27       48        Subscriber    97214               False
# 3              10       26        Subscriber    95060               False
# 4              67      319        Subscriber    94103                True
#
#    bike_station_class_vec
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True

# %% [markdown]
# #### When you can't write code in a vectorized format, swifter still makes parallel processing easy

# %%
# %time trips['date'] = trips['start_date'].swifter.apply(pd.to_datetime)
# Out:
# Wall time: 45.8 s

# %%
trips.head()
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4607        70  8/29/2013 14:42        San Jose City Hall
# 2  4130        71  8/29/2013 10:16   Mountain View City Hall
# 3  4251        77  8/29/2013 11:29        San Jose City Hall
# 4  4299        83  8/29/2013 12:02  South Van Ness at Market
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                10  8/29/2013 14:43        San Jose City Hall
# 2                27  8/29/2013 10:17   Mountain View City Hall
# 3                10  8/29/2013 11:30        San Jose City Hall
# 4                66  8/29/2013 12:04            Market at 10th
#
#    end_station_id  bike_id subscription_type zip_code  bike_station_class  \
# 0              66      520        Subscriber    94127                True
# 1              10      661        Subscriber    95138               False
# 2              27       48        Subscriber    97214               False
# 3              10       26        Subscriber    95060               False
# 4              67      319        Subscriber    94103                True
#
#    bike_station_class_vec                date
# 0                    True 2013-08-29 14:13:00
# 1                    True 2013-08-29 14:42:00
# 2                    True 2013-08-29 10:16:00
# 3                    True 2013-08-29 11:29:00
# 4                    True 2013-08-29 12:02:00

# %% [markdown]
# ### Multiple columns apply example

# %%
#def bikes_start_end(start_id,end_id):
#     return end_id-start_id
# %time trips["bikes_start_end_diff"] = trips[['start_station_id', 'end_station_id']].swifter.apply(lambda row: bikes_start_end(row["start_station_id"], row["end_station_id"]))

# %% [markdown]
# ### Rolling objects apply example

# %%
# %time trips["rolling_sum_duration"] = trips['duration'].swifter.rolling(10).apply(sum)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Pandas Apply', max=1.0, style=ProgressS…
# Wall time: 2min 32s

# %%
trips.iloc[10:15,:]
# Out:
#       id  duration       start_date              start_station_name  \
# 10  4549       125  8/29/2013 13:52                 Spear at Folsom
# 11  4498       126  8/29/2013 13:23                San Pedro Square
# 12  4965       129  8/29/2013 19:32  Mountain View Caltrain Station
# 13  4557       130  8/29/2013 13:57               2nd at South Park
# 14  4386       134  8/29/2013 12:31                 Clay at Battery
#
#     start_station_id         end_date                end_station_name  \
# 10                49  8/29/2013 13:55           Embarcadero at Bryant
# 11                 6  8/29/2013 13:25          Santa Clara at Almaden
# 12                28  8/29/2013 19:35  Mountain View Caltrain Station
# 13                64  8/29/2013 13:59               2nd at South Park
# 14                41  8/29/2013 12:33                 Beale at Market
#
#     end_station_id  bike_id subscription_type zip_code  bike_station_class  \
# 10              54      368        Subscriber    94109                True
# 11               4       26        Subscriber    95112               False
# 12              28      140        Subscriber    94041               False
# 13              64      371        Subscriber    94122                True
# 14              56      503        Subscriber    94109                True
#
#     bike_station_class_vec                date  rolling_sum_duration
# 10                    True 2013-08-29 13:52:00                 976.0
# 11                   False 2013-08-29 13:23:00                1032.0
# 12                    True 2013-08-29 19:32:00                1090.0
# 13                    True 2013-08-29 13:57:00                1143.0
# 14                    True 2013-08-29 12:31:00                1194.0
